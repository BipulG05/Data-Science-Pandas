# %% [markdown]
# # indian ai production pandas part- 17 and 18 and 19
# # Pandas merge() and concat()

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
                'Class':[9,10,11,12]})
df1
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2=pd.DataFrame({'ID':[1,2,3,4],
                'Name':['A','B','C','D']})
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D

# %%
pd.merge(df1,df2,on='ID')
# Out:
#    ID  Class Name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C
# 3   4     12    D

# %%
pd.merge(df2,df1,on='ID')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
df2=pd.DataFrame({'ID':[1,2,3,5],
                'Name':['A','B','C','D']})
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
pd.merge(df2,df1,on='ID')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11

# %%
pd.merge(df2,df1,on='ID',how='inner')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11

# %%
pd.merge(df2,df1,on='ID',how='left')
# Out:
#    ID Name  Class
# 0   1    A    9.0
# 1   2    B   10.0
# 2   3    C   11.0
# 3   5    D    NaN

# %%
pd.merge(df2,df1,on='ID',how='outer')
# Out:
#    ID Name  Class
# 0   1    A    9.0
# 1   2    B   10.0
# 2   3    C   11.0
# 3   5    D    NaN
# 4   4  NaN   12.0

# %%
pd.merge(df2,df1,on='ID',how='outer',indicator=True)
# Out:
#    ID Name  Class      _merge
# 0   1    A    9.0        both
# 1   2    B   10.0        both
# 2   3    C   11.0        both
# 3   5    D    NaN   left_only
# 4   4  NaN   12.0  right_only

# %%
df1
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   5    D

# %%
df2=pd.DataFrame({'ID':[5,6,7,8],
                'Name':['A','B','C','D']})
df2
# Out:
#    ID Name
# 0   5    A
# 1   6    B
# 2   7    C
# 3   8    D

# %%
pd.merge(df1,df2,left_index=True,right_index=True)
# Out:
#    ID_x  Class  ID_y Name
# 0     1      9     5    A
# 1     2     10     6    B
# 2     3     11     7    C
# 3     4     12     8    D

# %%
pd.merge(df1,df2)
# Out:
# Empty DataFrame
# Columns: [ID, Class, Name]
# Index: []

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
                'Class':[9,10,11,12]})
df1
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
df2=pd.DataFrame({'ID':[1,2,3,4],
                'Class':[9,10,11,12]})
df2
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   4     12

# %%
pd.merge(df1,df2,on='ID')
# Out:
#    ID  Class_x  Class_y
# 0   1        9        9
# 1   2       10       10
# 2   3       11       11
# 3   4       12       12

# %%
pd.merge(df1,df2,on='ID',suffixes=('_Higher','_Middle'))
# Out:
#    ID  Class_Higher  Class_Middle
# 0   1             9             9
# 1   2            10            10
# 2   3            11            11
# 3   4            12            12

# %%
import pandas as pd

# %%
sr1=pd.Series([0,1,2])
sr1
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
sr2=pd.Series([3,4,5])
sr2
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
pd.concat([sr1,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
sr2=pd.Series([3,4,5,6,7])
sr2
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
pd.concat([sr1,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
             'Name':['A','B','C','D'],
             'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[5,6,7,8],
             'Name':['E','F','G','H'],
             'Class':[9,10,11,12]})
df2
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2,df1],axis=1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   5    E      9   1    A      5
# 1   6    F     10   2    B      6
# 2   7    G     11   3    C      7
# 3   8    H     12   4    D      8

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 4   5    E      9
# 5   6    F     10
# 6   7    G     11
# 7   8    H     12

# %%
#pd.concat([df1,df2],axis=1,ignore_index=True)

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
             'Name':['A','B','C','D'],
             'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[3,4],
             'Name':['C','D'],
             'Class':[7,8]})
df2
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
pd.concat([df1,df2],axis=1,join='inner')
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      5   3    C      7
# 1   2    B      6   4    D      8

# %%
#pd.concat([df1,df2],axis=1,join_axes=[df1.index]) # not in this version

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
             'Name':['A','B','C','D'],
             'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[5,6,7,8],
             'Name':['E','F','G','H'],
             'Class':[9,10,11,12]})
df2
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2],keys=['df1','df2'])
# Out:
#        ID Name  Class
# df1 0   1    A      5
#     1   2    B      6
#     2   3    C      7
#     3   4    D      8
# df2 0   5    E      9
#     1   6    F     10
#     2   7    G     11
#     3   8    H     12

# %%
pd.concat([df1,df2],keys=['First DF','Sceand DF'])
# Out:
#              ID Name  Class
# First DF  0   1    A      5
#           1   2    B      6
#           2   3    C      7
#           3   4    D      8
# Sceand DF 0   5    E      9
#           1   6    F     10
#           2   7    G     11
#           3   8    H     12

# %%
pd.concat([df1,df2],axis=1,keys=['First DF','Sceand DF'])
# Out:
#   First DF            Sceand DF
#         ID Name Class        ID Name Class
# 0        1    A     5         5    E     9
# 1        2    B     6         6    F    10
# 2        3    C     7         7    G    11
# 3        4    D     8         8    H    12

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
             'Name':['A','B','C','D'],
             'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'Marks':[40,55,77,66]})
df2
# Out:
#    Marks
# 0     40
# 1     55
# 2     77
# 3     66

# %%
pd.concat([df1,df2])
# Out:
#     ID Name  Class  Marks
# 0  1.0    A    5.0    NaN
# 1  2.0    B    6.0    NaN
# 2  3.0    C    7.0    NaN
# 3  4.0    D    8.0    NaN
# 0  NaN  NaN    NaN   40.0
# 1  NaN  NaN    NaN   55.0
# 2  NaN  NaN    NaN   77.0
# 3  NaN  NaN    NaN   66.0

# %%
pd.concat([df1,df2],sort=True)
# Out:
#    Class   ID  Marks Name
# 0    5.0  1.0    NaN    A
# 1    6.0  2.0    NaN    B
# 2    7.0  3.0    NaN    C
# 3    8.0  4.0    NaN    D
# 0    NaN  NaN   40.0  NaN
# 1    NaN  NaN   55.0  NaN
# 2    NaN  NaN   77.0  NaN
# 3    NaN  NaN   66.0  NaN
