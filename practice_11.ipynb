# %% [markdown]
# # indian ai production pandas part- 20 and 21
# # Pandas join() and append()

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'A':[1,2,3],'B':[10,20,30]})
df2=pd.DataFrame({'C':[4,5,6],'D':[40,50,60]})
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.join(df2)
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50
# 2  3  30  6  60

# %%
df2.join(df1)
# Out:
#    C   D  A   B
# 0  4  40  1  10
# 1  5  50  2  20
# 2  6  60  3  30

# %%
df1=pd.DataFrame({'A':[1,2,3],'B':[10,20,30]},index=['a','b','c'])
display(df1)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30

# %%
df2.join(df1)
# Out:
#    C   D   A   B
# 0  4  40 NaN NaN
# 1  5  50 NaN NaN
# 2  6  60 NaN NaN

# %%
df2=pd.DataFrame({'C':[4,5,6],'D':[40,50,60]},index=['a','b','c'])
df2
# Out:
#    C   D
# a  4  40
# b  5  50
# c  6  60

# %%
df2.join(df1)
# Out:
#    C   D  A   B
# a  4  40  1  10
# b  5  50  2  20
# c  6  60  3  30

# %%
df2=pd.DataFrame({'C':[4,5],'D':[40,50]},index=['a','b'])
df2
# Out:
#    C   D
# a  4  40
# b  5  50

# %%
df1.join(df2)
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
df1.join(df2,how='left')
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
df1.join(df2,how='inner')
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50

# %%
df1.join(df2,how='outer')
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
df1.join(df2,how='right')
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50

# %%
df2=pd.DataFrame({'A':[4,5],'D':[40,50]},index=['a','b'])
df2
# Out:
#    A   D
# a  4  40
# b  5  50

# %%
df1.join(df2,lsuffix='_1')
# Out:
#    A_1   B    A     D
# a    1  10  4.0  40.0
# b    2  20  5.0  50.0
# c    3  30  NaN   NaN

# %%
df1.join(df2,rsuffix='_1')
# Out:
#    A   B  A_1     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
import pandas as pd

# %%
df3=pd.DataFrame({'A':[1,2,3],'B':[10,20,30]})
df4=pd.DataFrame({'A':[4,5,6],'B':[40,50,60]})
display(df3,df4)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    A   B
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df3.append(df4)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df3.append(df4,ignore_index=True)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50
# 5  6  60

# %%
df4.append(df3,ignore_index=True)
# Out:
#    A   B
# 0  4  40
# 1  5  50
# 2  6  60
# 3  1  10
# 4  2  20
# 5  3  30

# %%
df3=pd.DataFrame({'A':[1,2,3],'B':[10,20,30]})
df4=pd.DataFrame({'C':[4,5,6],'B':[40,50,60]})
display(df3,df4)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   B
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df3.append(df4,ignore_index=True)
# Out:
#      A   B    C
# 0  1.0  10  NaN
# 1  2.0  20  NaN
# 2  3.0  30  NaN
# 3  NaN  40  4.0
# 4  NaN  50  5.0
# 5  NaN  60  6.0
