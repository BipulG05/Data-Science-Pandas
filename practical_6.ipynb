# %% [markdown]
# # indian ai production pandas part- 8,9 and 10
# # Handling Missing Values in Python

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',na_values='not available')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill            no values       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',na_values=['not available','no values'])
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill            no values       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',na_values={'Companies':'no values','Growth':'not available'})
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',keep_default_na=False)
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                 NULL       2009  $10,573,990
# 5   6         Techline                 #N/A       2006  $13,898,119
# 6   7          Cityace                 #N/A       2010   $9,254,614
# 7   8   Kayelectronics                            2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557   NULL
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',keep_default_na=True)
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',na_filter=False)
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     7%
# ...

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv',na_filter=True)
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557     7%
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009           NaN
# 5   6         Techline               Health       2006           NaN
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Companies  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False      False      False    False     False   False   False
# 1  False  False      False      False    False     False   False   False
# 2  False  False      False      False    False     False   False   False
# 3  False  False      False      False    False     False   False    True
# 4  False  False      False      False     True     False   False    True
# 5  False  False      False      False     True     False   False    True
# 6  False  False      False      False    False     False   False   False
# 7  False  False      False      False    False     False   False   False
# 8  False  False      False      False    False     False   False   False
# 9  False  False      False      False    False     False   False   False

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Companies    0
# Inception    0
# Revenue      2
# Expenses     0
# Profit       0
# Growth       3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_10_1.csv')
df
# Out:
#    ID             Name            Companies  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009           NaN
# 5   6         Techline               Health       2006           NaN
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df.notnull()
# Out:
#      ID  Name  Companies  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True       True       True     True      True    True    True
# 1  True  True       True       True     True      True    True    True
# 2  True  True       True       True     True      True    True    True
# 3  True  True       True       True     True      True    True   False
# 4  True  True       True       True    False      True    True   False
# 5  True  True       True       True    False      True    True   False
# 6  True  True       True       True     True      True    True    True
# 7  True  True       True       True     True      True    True    True
# 8  True  True       True       True     True      True    True    True
# 9  True  True       True       True     True      True    True    True

# %%
df.notnull().sum()
# Out:
# ID           10
# Name         10
# Companies    10
# Inception    10
# Revenue       8
# Expenses     10
# Profit       10
# Growth        7
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 75

# %%
# Series
import numpy as np
sr=pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_S.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df.dropna()
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1)
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   5674893

# %%
df.dropna(how ='any')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1,how ='any')
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   5674893

# %%
df.dropna(how ='all')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_S.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_S.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN

# %%
df.dropna(how ='all')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN

# %%
df.dropna(thresh=2)
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN

# %%
df.dropna(thresh=4)
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df=pd.read_csv('D:\\python programs\\CSV File\\Fortune_S1.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN         IT Services         NaN    NaN

# %%
df.dropna(subset=['ID'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN

# %%
df.dropna(subset=['Name'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df.dropna(subset=['Profit'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN

# %%
df.dropna(inplace=True)
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
